# %%
import pandas as pd

# %%
bus_line_data = pd.read_excel("bus_line_data.xlsx")

# %%
bus_line_data
# Out:
#    adr_dong  버스노선수
# 0       가좌동      4
# 1       강매동      6
# 2       고양동      0
# 3       관산동      4
# 4       구산동     10
# 5       내곡동      6
# 6       내유동      4
# 7       대자동      5
# 8       대장동      3
# 9       대화동     13
# 10      덕은동      2
# 11      덕이동      5
# 12      도내동      0
# 13      동산동      1
# 14      마두동     16
# 15      문봉동      0
# 16      백석동     15
# 17      법곳동     11
# 18      벽제동      0
# 19      북한동      0
# 20     사리현동      1
# 21      산황동      0
# 22      삼송동      4
# 23      선유동      0
# 24      설문동      0
# 25      성사동      5
# 26      성석동      0
# 27      식사동      4
# 28      신원동      3
# 29      신평동      0
# 30      오금동      0
# 31      용두동      1
# 32      원당동      1
# 33      원흥동      2
# 34      일산동      4
# 35      장항동     26
# 36     정발산동     10
# 37      주교동      7
# 38      주엽동     12
# 39      중산동      4
# 40      지영동      0
# 41      지축동      3
# 42      탄현동      3
# 43      토당동     25
# 44       풍동      3
# 45      행신동      9
# 46     행주내동      2
# 47     행주외동     12
# 48      향동동      0
# 49      현천동     17
# 50      화전동      8
# 51      화정동     13
# 52      효자동      0

# %%
bus_line_data.columns
# Out:
# Index(['adr_dong', '버스노선수'], dtype='object')

# %%
# 각 값들 리스트로 만들기
adr_dong = list(bus_line_data['adr_dong'])
bus_num = list(bus_line_data['버스노선수'])

# %%
bus_dict = {}

for i in range(0, len(adr_dong)):
    bus_dict[adr_dong[i]] = bus_num[i]

print(bus_dict)
# Out:
# {'가좌동': 4, '강매동': 6, '고양동': 0, '관산동': 4, '구산동': 10, '내곡동': 6, '내유동': 4, '대자동': 5, '대장동': 3, '대화동': 13, '덕은동': 2, '덕이동': 5, '도내동': 0, '동산동': 1, '마두동': 16, '문봉동': 0, '백석동': 15, '법곳동': 11, '벽제동': 0, '북한동': 0, '사리현동': 1, '산황동': 0, '삼송동': 4, '선유동': 0, '설문동': 0, '성사동': 5, '성석동': 0, '식사동': 4, '신원동': 3, '신평동': 0, '오금동': 0, '용두동': 1, '원당동': 1, '원흥동': 2, '일산동': 4, '장항동': 26, '정발산동': 10, '주교동': 7, '주엽동': 12, '중산동': 4, '지영동': 0, '지축동': 3, '탄현동': 3, '토당동': 25, '풍동': 3, '행신동': 9, '행주내동': 2, '행주외동': 12, '향동동': 0, '현천동': 17, '화전동': 8, '화정동': 13, '효자동': 0}
